# %% [markdown]
# # Percolation Test Results

# %%
from Percolation import *

# %%
for i in range(10):
    size = (i + 2) ** 2
    mc = MonteCarlo(size, 100)
    print(f"Tests for network size: {size}")
    print("__________________________")
    mc.monte_carlo_percolation_test('PathCompression', randomized=False, seed_value=3)
    print()
    mc.monte_carlo_percolation_test('WeightedQuickUnion', randomized=False, seed_value=3)
    print()
    mc.monte_carlo_percolation_test('QuickUnion', randomized=False, seed_value=3)
    print()
    mc.monte_carlo_percolation_test('QuickFind', randomized=False, seed_value=3)
    print()

# %%
pc = 'PathCompression'
wqu = 'WeightedQuickUnion'
pc_times = []
wqu_times = []
for i in range(1000, 20001, 1000):
    size = 25
    times = i
    mc = MonteCarlo(size, i)
    print(f"Size {size} x {size} at {i} iterations")
    print("---------------------------------------")
    print(f"Algorithm: {pc}")
    pc_times.append(mc.monte_carlo_percolation_test('PathCompression', randomized=False, seed_value=3, show_results=False)[1])
    print()
    print(f"Algorithm: {wqu}")
    wqu_times.append(mc.monte_carlo_percolation_test('WeightedQuickUnion', randomized=False, seed_value=3, show_results=False)[1])
    print()
# Out:
# Size 25 x 25 at 100 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 0.6741199493408203 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.5914521217346191 s
#
# Size 25 x 25 at 200 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 1.168147087097168 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 1.1923680305480957 s
#
# Size 25 x 25 at 300 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 1.7612240314483643 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 1.7332689762115479 s
#
# Size 25 x 25 at 400 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 2.3730130195617676 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 2.3570780754089355 s
#
# Size 25 x 25 at 500 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 2.9794609546661377 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 2.959280014038086 s
#
# Size 25 x 25 at 600 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 3.6468567848205566 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 3.6326019763946533 s
#
# Size 25 x 25 at 700 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 4.336077928543091 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 4.328260898590088 s
#
# Size 25 x 25 at 800 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 5.106283903121948 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 5.0497729778289795 s
#
# Size 25 x 25 at 900 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 5.812261343002319 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 5.833129167556763 s
#
# Size 25 x 25 at 1000 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 6.613631248474121 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 6.594038009643555 s
#
# Size 25 x 25 at 1100 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 7.439762830734253 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 7.401473045349121 s
#
# Size 25 x 25 at 1200 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 8.203099966049194 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 8.044517755508423 s
#
# Size 25 x 25 at 1300 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 8.854433059692383 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 8.91983413696289 s
#
# Size 25 x 25 at 1400 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 9.90394902229309 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 9.70126986503601 s
#
# Size 25 x 25 at 1500 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 10.578529834747314 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 10.401223182678223 s
#
# Size 25 x 25 at 1600 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 11.254508018493652 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 11.087886095046997 s
#
# Size 25 x 25 at 1700 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 11.984467029571533 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 11.833307027816772 s
#
# Size 25 x 25 at 1800 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 12.74329686164856 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 12.60102915763855 s
#
# Size 25 x 25 at 1900 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 13.40745496749878 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 13.208929061889648 s
#
# Size 25 x 25 at 2000 iterations
# -------------------------------------------------
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 14.153555870056152 s
#
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 13.852697134017944 s

# %%
import matplotlib.pyplot as plt

# create data
x = [x for x in range(1000, 20001, 1000)]
y1 = pc_times
y2 = wqu_times
  
# plot lines
plt.plot(x, y1, label = "path compression")
plt.plot(x, y2, label = "weighted quick union")
plt.legend()
plt.show()
