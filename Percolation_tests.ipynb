# %% [markdown]
# # Percolation Test Results

# %%
from Percolation import *

# %%
for i in range(8):
    size = (i + 2) ** 2
    mc = MonteCarlo(size, 100)
    print(f"Tests for network size: {size}")
    print("__________________________")
    mc.monte_carlo_percolation_test('PathCompression', randomized=False, seed_value=3)
    print()
    mc.monte_carlo_percolation_test('WeightedQuickUnion', randomized=False, seed_value=3)
    print()
    mc.monte_carlo_percolation_test('QuickUnion', randomized=False, seed_value=3)
    print()
# Out:
# Tests for network size: 4
# __________________________
# Percolation Threshold Average: 60.5%
# Board Size: 4
# Iterations: 100
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 0.02103710174560547 s
#
# Percolation Threshold Average: 60.5%
# Board Size: 4
# Iterations: 100
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.01849198341369629 s
#
# Percolation Threshold Average: 60.5%
# Board Size: 4
# Iterations: 100
# Algorithm: QuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.017933130264282227 s
#
# Tests for network size: 9
# __________________________
# Percolation Threshold Average: 59.5553%
# Board Size: 9
# Iterations: 100
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 0.05054903030395508 s
#
# Percolation Threshold Average: 59.5553%
# Board Size: 9
# Iterations: 100
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.044877052307128906 s
#
# Percolation Threshold Average: 59.5553%
# Board Size: 9
# Iterations: 100
# Algorithm: QuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.04255104064941406 s
#
# Tests for network size: 16
# __________________________
# Percolation Threshold Average: 59.078%
# Board Size: 16
# Iterations: 100
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 0.18342804908752441 s
#
# Percolation Threshold Average: 59.078%
# Board Size: 16
# Iterations: 100
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.16930890083312988 s
#
# Percolation Threshold Average: 59.078%
# Board Size: 16
# Iterations: 100
# Algorithm: QuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.17381691932678223 s
#
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 59.4672%
# Board Size: 25
# Iterations: 100
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 0.6158320903778076 s
#
# Percolation Threshold Average: 59.4672%
# Board Size: 25
# Iterations: 100
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.6353271007537842 s
#
# Percolation Threshold Average: 59.4672%
# Board Size: 25
# Iterations: 100
# Algorithm: QuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.6800258159637451 s
#
# Tests for network size: 36
# __________________________
# Percolation Threshold Average: 58.7181%
# Board Size: 36
# Iterations: 100
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 1.7289528846740723 s
#
# Percolation Threshold Average: 58.7181%
# Board Size: 36
# Iterations: 100
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 1.6273610591888428 s
#
# Percolation Threshold Average: 58.7181%
# Board Size: 36
# Iterations: 100
# Algorithm: QuickUnion
# monte_carlo_percolation_test: Elapsed time of 1.7720670700073242 s
#
# Tests for network size: 49
# __________________________
# Percolation Threshold Average: 59.2573%
# Board Size: 49
# Iterations: 100
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 4.031098127365112 s
#
# Percolation Threshold Average: 59.2573%
# Board Size: 49
# Iterations: 100
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 4.006799936294556 s
#
# Percolation Threshold Average: 59.2573%
# Board Size: 49
# Iterations: 100
# Algorithm: QuickUnion
# monte_carlo_percolation_test: Elapsed time of 4.283297061920166 s
#
# Tests for network size: 64
# __________________________
# Percolation Threshold Average: 59.41%
# Board Size: 64
# Iterations: 100
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 8.638250827789307 s
#
# Percolation Threshold Average: 59.41%
# Board Size: 64
# Iterations: 100
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 8.863417148590088 s
#
# Percolation Threshold Average: 59.41%
# Board Size: 64
# Iterations: 100
# Algorithm: QuickUnion
# monte_carlo_percolation_test: Elapsed time of 9.553864002227783 s
#
# Tests for network size: 81
# __________________________
# Percolation Threshold Average: 59.068%
# Board Size: 81
# Iterations: 100
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 18.977550745010376 s
#
# Percolation Threshold Average: 59.068%
# Board Size: 81
# Iterations: 100
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 18.47431492805481 s
#
# Percolation Threshold Average: 59.068%
# Board Size: 81
# Iterations: 100
# Algorithm: QuickUnion
# monte_carlo_percolation_test: Elapsed time of 20.868834018707275 s

# %%
for i in range(100, 1000, 100):
    size = 25
    times = i
    mc = MonteCarlo(size, i)
    print(f"Tests for network size: {size}")
    print("__________________________")
    mc.monte_carlo_percolation_test('PathCompression', randomized=False, seed_value=3)
    print()
    mc.monte_carlo_percolation_test('WeightedQuickUnion', randomized=False, seed_value=3)
    print()
# Out:
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 59.4672%
# Board Size: 25
# Iterations: 100
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 0.6501519680023193 s
#
# Percolation Threshold Average: 59.4672%
# Board Size: 25
# Iterations: 100
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 0.6074888706207275 s
#
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 58.988%
# Board Size: 25
# Iterations: 200
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 1.2583448886871338 s
#
# Percolation Threshold Average: 58.988%
# Board Size: 25
# Iterations: 200
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 1.316673994064331 s
#
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 59.048%
# Board Size: 25
# Iterations: 300
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 1.900221347808838 s
#
# Percolation Threshold Average: 59.048%
# Board Size: 25
# Iterations: 300
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 1.8293569087982178 s
#
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 59.2304%
# Board Size: 25
# Iterations: 400
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 2.6343801021575928 s
#
# Percolation Threshold Average: 59.2304%
# Board Size: 25
# Iterations: 400
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 2.499333143234253 s
#
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 59.2362%
# Board Size: 25
# Iterations: 500
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 3.1692306995391846 s
#
# Percolation Threshold Average: 59.2362%
# Board Size: 25
# Iterations: 500
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 3.243985891342163 s
#
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 59.2637%
# Board Size: 25
# Iterations: 600
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 3.856346845626831 s
#
# Percolation Threshold Average: 59.2637%
# Board Size: 25
# Iterations: 600
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 3.740530014038086 s
#
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 59.2992%
# Board Size: 25
# Iterations: 700
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 4.451427936553955 s
#
# Percolation Threshold Average: 59.2992%
# Board Size: 25
# Iterations: 700
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 4.560774803161621 s
#
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 59.2706%
# Board Size: 25
# Iterations: 800
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 5.34139609336853 s
#
# Percolation Threshold Average: 59.2706%
# Board Size: 25
# Iterations: 800
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 5.355776071548462 s
#
# Tests for network size: 25
# __________________________
# Percolation Threshold Average: 59.2009%
# Board Size: 25
# Iterations: 900
# Algorithm: PathCompression
# monte_carlo_percolation_test: Elapsed time of 6.277321100234985 s
#
# Percolation Threshold Average: 59.2009%
# Board Size: 25
# Iterations: 900
# Algorithm: WeightedQuickUnion
# monte_carlo_percolation_test: Elapsed time of 6.370699882507324 s
